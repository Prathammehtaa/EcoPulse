# %%
import pandas as pd

# %%
weather_df = pd.read_parquet('/Users/pratham/code/MLops/EcoPulse/Pratham/data/weather_data_processed.parquet')
grid_df = pd.read_parquet('/Users/pratham/code/MLops/EcoPulse/Pratham/data/grid_data_processed.parquet')
merged_df = pd.read_parquet('/Users/pratham/code/MLops/EcoPulse/Pratham/data/merged_dataset.parquet')
feature_df = pd.read_parquet('/Users/pratham/code/MLops/EcoPulse/Pratham/data/feature_table.parquet')

# %%
print(weather_df.head())
# Out:
#                    datetime         zone  temperature_2m_c  \
# 0 2024-01-01 00:00:00+00:00  US-MIDA-PJM               2.8
# 1 2024-01-01 01:00:00+00:00  US-MIDA-PJM               1.9
# 2 2024-01-01 02:00:00+00:00  US-MIDA-PJM               1.6
# 3 2024-01-01 03:00:00+00:00  US-MIDA-PJM               1.2
# 4 2024-01-01 04:00:00+00:00  US-MIDA-PJM               1.3
#
#    wind_speed_100m_ms  cloud_cover_pct  shortwave_radiation_wm2  rain_mm  \
# 0                11.2               18                      0.0      0.0
# 1                14.1               39                      0.0      0.0
# 2                15.5               79                      0.0      0.0
# 3                12.3               96                      0.0      0.0
# 4                15.4              100                      0.0      0.1
#
#    snowfall_cm  weather_code
# 0          0.0             0
# 1          0.0             1
# 2          0.0             2
# 3          0.0             3
# ...

# %%
print(weather_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35088 entries, 0 to 35087
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   datetime                 35088 non-null  datetime64[ns, UTC]
#  1   zone                     35088 non-null  object
#  2   temperature_2m_c         35088 non-null  float64
#  3   wind_speed_100m_ms       35088 non-null  float64
#  4   cloud_cover_pct          35088 non-null  int64
#  5   shortwave_radiation_wm2  35088 non-null  float64
#  6   rain_mm                  35088 non-null  float64
#  7   snowfall_cm              35088 non-null  float64
#  8   weather_code             35088 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2), object(1)
# memory usage: 2.4+ MB
# None

# %%
print(weather_df.columns)
# Out:
# Index(['datetime', 'zone', 'temperature_2m_c', 'wind_speed_100m_ms',
#        'cloud_cover_pct', 'shortwave_radiation_wm2', 'rain_mm', 'snowfall_cm',
#        'weather_code'],
#       dtype='object')

# %%
print(grid_df.info())
print(merged_df.info())
print(feature_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35088 entries, 0 to 35087
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   datetime                              35088 non-null  datetime64[ns, UTC]
#  1   zone                                  35088 non-null  object
#  2   carbon_intensity_gco2_per_kwh         35088 non-null  int64
#  3   carbon_free_energy_pct                35088 non-null  int64
#  4   carbon_intensity_fossil_gco2_per_kwh  35088 non-null  float64
#  5   renewable_energy_pct                  35088 non-null  int64
#  6   total_load_mw                         35088 non-null  float64
#  7   net_load_mw                           35088 non-null  float64
#  8   aws_region                            35088 non-null  object
#  9   gcp_region                            35088 non-null  object
# ...
